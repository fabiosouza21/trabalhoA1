# %%
import matplotlib.pyplot as plt
from numpy import *

# %%
x = linspace(0, 50, 5)
y = linspace(0, 80, 5)
f = linspace(0, 80, 5)
g = linspace(10, 80, 5)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Retas que se cruzam')
plt.plot(x, y)
plt.plot(f, g)
plt.show()

# %%
x = linspace(0, 50, 5)
y = linspace(5, 70, 5)
f = linspace(0, 70, 5)
g = linspace(0, 70, 5)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Retas que se cruzam')
plt.plot(x, y)
plt.plot(f, g)
plt.show()
